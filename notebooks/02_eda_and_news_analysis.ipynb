# %% [markdown]
# # Notebook 02: Análisis Exploratorio de Datos (EDA) y Detección de Shocks
# **Proyecto:** Análisis SARIMAX - Starbucks Corporation (SBUX)
# **Investigador:** Frankli Zeña Zeña
#
# ---
# ## Introducción
# En este cuaderno realizaremos un análisis estadístico profundo de la serie de tiempo de Starbucks. Nos enfocaremos en identificar los momentos de mayor volatilidad mediante el análisis de volumen, lo cual nos permitirá correlacionar datos cuantitativos con eventos cualitativos (noticias).

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %%
# Configuración de estilo para el informe
plt.style.use('seaborn-v0_8-whitegrid')
sns.set_palette("viridis")

# Carga de datos procesados en el Notebook 01
df = pd.read_csv('../data/processed/SBUX_clean.csv', index_col=0, parse_dates=True)

print(f"Datos cargados correctamente. Rango: {df.index.min()} a {df.index.max()}")
df
# Out:
# Datos cargados correctamente. Rango: 2021-03-15 00:00:00 a 2026-02-13 00:00:00
#             Adj Close    Volume  Vol_Avg_20  Vol_Anomaly  Log_Return
# Date
# 2021-03-15  97.091217   7107300   6295740.0        False    0.010060
# 2021-03-16  99.266632  11376200   6618145.0        False    0.022159
# 2021-03-17  98.482056  10128400   6837875.0        False   -0.007935
# 2021-03-18  95.950020   7813400   7023610.0        False   -0.026047
# 2021-03-19  94.808807  21452000   7889765.0         True   -0.011965
# ...               ...       ...         ...          ...         ...
# 2026-02-09  98.345779   7150600  11434955.0        False   -0.004737
# 2026-02-10  96.905067   8543500  11497655.0        False   -0.014758
# 2026-02-11  98.484879   6949100  11567015.0        False    0.016171
# 2026-02-12  96.139999   9537300  11625220.0        False   -0.024098
# 2026-02-13  93.790001   8948000  11572535.0        False   -0.024747
#
# [1237 rows x 5 columns]

# %% [markdown]
# ### 1. Estadísticas Descriptivas
# Calculamos las métricas fundamentales para entender la distribución de los precios y los retornos logarítmicos. La **curtosis** alta nos indicará la presencia de valores atípicos (shocks de mercado).

# %%
# Cálculo de métricas sobre Retornos Logarítmicos
stats = df['Log_Return'].describe()
kurt = df['Log_Return'].kurt()
skew = df['Log_Return'].skew()

print("--- Resumen Estadístico de Retornos ---")
print(stats)
print(f"\nCurtosis: {kurt:.4f} (Valores > 3 indican colas pesadas/shocks)")
print(f"Sesgo: {skew:.4f}")

# Histograma de retornos para ver la "normalidad"
plt.figure(figsize=(10, 5))
sns.histplot(df['Log_Return'], kde=True, color='darkgreen')
plt.title('Distribución de Retornos Logarítmicos - SBUX')
plt.show()
# Out:
# --- Resumen Estadístico de Retornos ---
# count    1237.000000
# mean       -0.000020
# std         0.019517
# min        -0.172896
# 25%        -0.009325
# 50%        -0.000086
# 75%         0.009154
# max         0.219111
# Name: Log_Return, dtype: float64
#
# Curtosis: 21.0012 (Valores > 3 indican colas pesadas/shocks)
# Sesgo: 0.6574

# %% [markdown]
# ### 2. Identificación de Anomalías de Volumen
# Filtramos los días donde el volumen operado superó el doble de su media móvil de 20 días. Estos puntos representan momentos de alta convicción en el mercado, usualmente vinculados a noticias institucionales.

# %%
# Filtrar los registros donde Vol_Anomaly es True
anomalies_list = df[df['Vol_Anomaly'] == True].copy()
anomalies_list[['Adj Close', 'Volume', 'Log_Return']]
# Out:
#              Adj Close     Volume  Log_Return
# Date
# 2021-03-19   94.808807   21452000   -0.011965
# 2021-04-28  100.211693   14793500   -0.032818
# 2021-06-25  101.183266   12171200    0.009332
# 2021-09-15  103.013725   11556200   -0.036150
# 2021-10-29   95.312874   27419600   -0.065057
# 2021-11-01   98.664597   14184600    0.034561
# 2022-01-20   86.383369   20311500   -0.011943
# 2022-03-16   79.283936   21207900    0.050324
# 2022-03-18   81.270325   23784200    0.021889
# 2022-05-04   74.050323   30199700    0.093805
# 2022-08-03   79.714462   12915700    0.041648
# 2022-09-13   80.692276   16033600   -0.013906
# 2022-09-14   85.156792   24320600    0.053851
# 2022-10-24   76.944275   16499300   -0.056289
# 2022-11-04   84.385155   20194300    0.081386
# 2023-02-03   96.363548   15200500   -0.045452
# 2023-05-03   96.530693   24388600   -0.096219
# 2023-06-23   91.766983   18770100   -0.025204
# 2023-07-21   95.947548   20370300    0.019048
# 2023-08-02   95.303658   14463100    0.008555
# 2023-11-01   85.698753   14292500   -0.009696
# 2023-11-02   93.823029   23396300    0.090572
# 2023-11-03   96.299698   15995700    0.026055
# 2024-01-30   88.744881   17625200    0.002981
# 2024-01-31   87.754410   26751800   -0.011224
# 2024-03-15   85.520912   18136300   -0.016944
# 2024-05-01   70.641098   66610700   -0.172896
# 2024-06-21   76.407265   25648400    0.002380
# 2024-07-19   75.795311   32965900    0.066230
# 2024-08-13   91.696365  157215500    0.219111
# 2024-08-14   89.784035   45737800   -0.021076
# 2024-10-23   93.933990   18858800    0.008536
# 2024-12-20   85.145760   26477500   -0.008940
# 2025-01-29  105.094093   40769300    0.078225
# 2025-04-03   85.890114   20490100   -0.118966
# 2025-04-07   77.851898   26099400   -0.025911
# 2025-04-09   86.298836   26668100    0.106890
# 2025-04-30   77.900558   41297000   -0.058234
# 2025-06-27   90.267754   21491600    0.002936
# 2025-07-29   91.100761   20923600   -0.007609
# 2025-07-30   90.904762   44794700   -0.002154
# 2026-01-21   95.812111   17118100    0.029146
# 2026-01-28   94.550255   25961600   -0.005868

# %% [markdown]
# #### 2.1. Visualización de Shocks vs Precio
# Superponemos las anomalías detectadas sobre la serie de precios. Este gráfico es fundamental para el informe final, ya que justifica visualmente la necesidad de un modelo que considere la volatilidad.

# %%
import plotly.graph_objects as go

# %%
fig = go.Figure()

# 1. Trazar el precio base
fig.add_trace(go.Scatter(
    x=df.index, 
    y=df['Adj Close'],
    mode="lines", 
    name="Precio SBUX",
    line=dict(color="green", width=1) # Verde tenue
))

# 2. Resaltar Anomalías (Puntos Rojos)
anomalies = df[df['Vol_Anomaly'] == True]

fig.add_trace(go.Scatter(
    x=anomalies.index, 
    y=anomalies['Adj Close'],
    mode="markers", 
    name="Anomalía de Volumen",
    marker=dict(color="red", size=8, symbol="circle"),
    # Texto que aparecerá al pasar el cursor
    text=[f"Volumen: {v:,.0f}" for v in anomalies['Volume']],
    hovertemplate="<b>Fecha:</b> %{x}<br><b>Precio:</b> $%{y:.2f}<br>%{text}<extra></extra>"
))

fig.update_layout(
    title="Detección Interactiva de Shocks Externos (Picos de Volumen)",
    xaxis_title="Fecha",
    yaxis_title="Precio (USD)",
    hovermode="closest",
    template="plotly_white",
    width=1200, 
    height=600
)

fig.show()

# %% [markdown]
# #### 2.2. Herramienta de Investigación de Noticias
# Para completar el archivo `news_history.csv`, utilizaremos los links generados a continuación para identificar qué evento ocurrió en las fechas de mayor anomalía.

# %%
import webbrowser

# %%
print("--- BUSCADOR DE NOTICIAS HISTÓRICAS ---")

for date in anomalies_list.index:
    d_str = date.strftime('%Y-%m-%d') #Formato (YYYY-MM-DD)
    search_url = f"https://www.google.com/search?q=Starbucks+news+{d_str}&tbm=nws"
    
    print(f"Fecha: {d_str} | Buscar: {search_url}")
# Out:
# --- BUSCADOR DE NOTICIAS HISTÓRICAS ---
# Fecha: 2021-03-19 | Buscar: https://www.google.com/search?q=Starbucks+news+2021-03-19&tbm=nws
# Fecha: 2021-04-28 | Buscar: https://www.google.com/search?q=Starbucks+news+2021-04-28&tbm=nws
# Fecha: 2021-06-25 | Buscar: https://www.google.com/search?q=Starbucks+news+2021-06-25&tbm=nws
# Fecha: 2021-09-15 | Buscar: https://www.google.com/search?q=Starbucks+news+2021-09-15&tbm=nws
# Fecha: 2021-10-29 | Buscar: https://www.google.com/search?q=Starbucks+news+2021-10-29&tbm=nws
# Fecha: 2021-11-01 | Buscar: https://www.google.com/search?q=Starbucks+news+2021-11-01&tbm=nws
# Fecha: 2022-01-20 | Buscar: https://www.google.com/search?q=Starbucks+news+2022-01-20&tbm=nws
# Fecha: 2022-03-16 | Buscar: https://www.google.com/search?q=Starbucks+news+2022-03-16&tbm=nws
# Fecha: 2022-03-18 | Buscar: https://www.google.com/search?q=Starbucks+news+2022-03-18&tbm=nws
# Fecha: 2022-05-04 | Buscar: https://www.google.com/search?q=Starbucks+news+2022-05-04&tbm=nws
# Fecha: 2022-08-03 | Buscar: https://www.google.com/search?q=Starbucks+news+2022-08-03&tbm=nws
# Fecha: 2022-09-13 | Buscar: https://www.google.com/search?q=Starbucks+news+2022-09-13&tbm=nws
# Fecha: 2022-09-14 | Buscar: https://www.google.com/search?q=Starbucks+news+2022-09-14&tbm=nws
# Fecha: 2022-10-24 | Buscar: https://www.google.com/search?q=Starbucks+news+2022-10-24&tbm=nws
# Fecha: 2022-11-04 | Buscar: https://www.google.com/search?q=Starbucks+news+2022-11-04&tbm=nws
# Fecha: 2023-02-03 | Buscar: https://www.google.com/search?q=Starbucks+news+2023-02-03&tbm=nws
# Fecha: 2023-05-03 | Buscar: https://www.google.com/search?q=Starbucks+news+2023-05-03&tbm=nws
# Fecha: 2023-06-23 | Buscar: https://www.google.com/search?q=Starbucks+news+2023-06-23&tbm=nws
# Fecha: 2023-07-21 | Buscar: https://www.google.com/search?q=Starbucks+news+2023-07-21&tbm=nws
# Fecha: 2023-08-02 | Buscar: https://www.google.com/search?q=Starbucks+news+2023-08-02&tbm=nws
# Fecha: 2023-11-01 | Buscar: https://www.google.com/search?q=Starbucks+news+2023-11-01&tbm=nws
# Fecha: 2023-11-02 | Buscar: https://www.google.com/search?q=Starbucks+news+2023-11-02&tbm=nws
# Fecha: 2023-11-03 | Buscar: https://www.google.com/search?q=Starbucks+news+2023-11-03&tbm=nws
# Fecha: 2024-01-30 | Buscar: https://www.google.com/search?q=Starbucks+news+2024-01-30&tbm=nws
# Fecha: 2024-01-31 | Buscar: https://www.google.com/search?q=Starbucks+news+2024-01-31&tbm=nws
# Fecha: 2024-03-15 | Buscar: https://www.google.com/search?q=Starbucks+news+2024-03-15&tbm=nws
# Fecha: 2024-05-01 | Buscar: https://www.google.com/search?q=Starbucks+news+2024-05-01&tbm=nws
# Fecha: 2024-06-21 | Buscar: https://www.google.com/search?q=Starbucks+news+2024-06-21&tbm=nws
# Fecha: 2024-07-19 | Buscar: https://www.google.com/search?q=Starbucks+news+2024-07-19&tbm=nws
# Fecha: 2024-08-13 | Buscar: https://www.google.com/search?q=Starbucks+news+2024-08-13&tbm=nws
# Fecha: 2024-08-14 | Buscar: https://www.google.com/search?q=Starbucks+news+2024-08-14&tbm=nws
# Fecha: 2024-10-23 | Buscar: https://www.google.com/search?q=Starbucks+news+2024-10-23&tbm=nws
# Fecha: 2024-12-20 | Buscar: https://www.google.com/search?q=Starbucks+news+2024-12-20&tbm=nws
# Fecha: 2025-01-29 | Buscar: https://www.google.com/search?q=Starbucks+news+2025-01-29&tbm=nws
# Fecha: 2025-04-03 | Buscar: https://www.google.com/search?q=Starbucks+news+2025-04-03&tbm=nws
# Fecha: 2025-04-07 | Buscar: https://www.google.com/search?q=Starbucks+news+2025-04-07&tbm=nws
# Fecha: 2025-04-09 | Buscar: https://www.google.com/search?q=Starbucks+news+2025-04-09&tbm=nws
# Fecha: 2025-04-30 | Buscar: https://www.google.com/search?q=Starbucks+news+2025-04-30&tbm=nws
# Fecha: 2025-06-27 | Buscar: https://www.google.com/search?q=Starbucks+news+2025-06-27&tbm=nws
# Fecha: 2025-07-29 | Buscar: https://www.google.com/search?q=Starbucks+news+2025-07-29&tbm=nws
# Fecha: 2025-07-30 | Buscar: https://www.google.com/search?q=Starbucks+news+2025-07-30&tbm=nws
# Fecha: 2026-01-21 | Buscar: https://www.google.com/search?q=Starbucks+news+2026-01-21&tbm=nws
# Fecha: 2026-01-28 | Buscar: https://www.google.com/search?q=Starbucks+news+2026-01-28&tbm=nws

# %%
# Cargar registro de noticias (asegúrate de haberlo creado en la carpeta data/external/)
news = pd.read_csv('../data/external/news_history.csv', index_col=0, parse_dates=True)
news
# Out:
#                                       Evento     Categoria    Efecto  \
# Fecha
# 2021-03-16     Luckin reestructuración deuda   Competencia  negativo
# 2021-03-17  50th Anniversary Blend Starbucks   Fundamental  positivo
# 2021-03-18           Expansión pickup Dunkin   Competencia  negativo
# 2021-03-19         Costa Express inteligente   Competencia  negativo
# 2021-03-20           McCafe integrado en app   Competencia  negativo
# 2021-04-28                Resultados Q2 FY21      Earnings  positivo
# 2021-06-25                   Escasez insumos        Demand  negativo
# 2021-09-15                 Aumento dividendo    Dividendos  positivo
# 2021-10-29          Subida salarial partners        Costos  negativo
# 2021-11-01   CocaCola BodyArmor distribucion   Competencia  negativo
# 2022-01-20                  Luckin relisting   Competencia  negativo
# 2022-03-16            Regreso Howard Schultz    Management  positivo
# 2022-03-18               Suspension buybacks    Financiero  negativo
# 2022-05-04                Caida ventas China      Earnings  negativo
# 2022-08-03     Bebidas frias impulsan ventas      Earnings  positivo
# 2022-08-09            Expansion Luckin China   Competencia  negativo
# 2022-09-13          Investor Day reinvention     Strategic  positivo
# 2022-09-14               Upgrades WallStreet        Market  positivo
# 2022-10-24                 Digital McDonalds   Competencia  negativo
# 2022-11-04                   Ingresos record      Earnings  positivo
# 2023-02-03                   Debilidad China      Earnings  negativo
# 2023-05-03       Primer trimestre Narasimhan      Earnings  positivo
# 2023-06-23                   Huelga sindical  Reputacional  negativo
# 2023-07-21              Luckin 10000 tiendas   Competencia  negativo
# 2023-07-21           Nuevo jefe supply chain    Management    neutro
# 2023-08-02            Ventas globales crecen      Earnings  positivo
# 2023-08-02       Siren System automatizacion     Operativo  positivo
# 2023-11-01                      Holiday menu    Estacional  positivo
# 2023-11-02                Resultados Q4 FY23      Earnings  positivo
# 2023-11-03          Mejora rating crediticio    Financiero  positivo
# 2023-12-04                  CosMcs McDonalds   Competencia  negativo
# 2024-01-30                 Q1 FY24 decepcion      Earnings  negativo
# 2024-01-31           Boicots internacionales  Reputacional  negativo
# 2024-03-15                Cierre Odyssey NFT     Strategic  positivo
# 2024-05-01                   Colapso Q2 FY24      Earnings  negativo
# 2024-06-21              Menu value defensivo   Competencia  negativo
# 2024-07-19                   Entrada Elliott        Market  positivo
# 2024-08-13            Nuevo CEO Brian Niccol    Management  positivo
# 2024-08-14                Salto bursatil 24%        Market  positivo
# 2024-10-23                 Suspende guidance     Strategic  negativo
# 2024-11-03              Luckin expansion USA   Competencia  negativo
# 2024-12-20   Promociones navidad competencia    Estacional  negativo
# 2025-01-29            Primer earnings Niccol      Earnings  positivo
# 2025-04-03               Reunion accionistas       Cultura  positivo
# 2025-04-07            Subsidios Luckin China   Competencia  negativo
# 2025-04-09     Innovaciones RTD competidores   Competencia  negativo
# 2025-04-30                Resultados Q2 FY25      Earnings  negativo
# 2025-05-24                     Cierre CosMcs   Competencia  positivo
# 2025-06-27                Value deals McCafe   Competencia  negativo
# 2025-07-02           Luckin entra Nueva York   Competencia  negativo
# 2025-07-29               Volatilidad Arabica         Macro  negativo
# 2025-07-30                Resultados Q3 FY25      Earnings  positivo
# 2026-01-14           CocaCola no vende Costa   Competencia  negativo
# 2026-01-21           Guerra vending machines   Competencia  negativo
# 2026-01-28                Q1 FY26 turnaround      Earnings  positivo
#
#                                                        Fuente  \
# Fecha
# 2021-03-16  https://investor.luckincoffee.com/news-release...
# 2021-03-17  https://www.gcrmag.com/starbucks-celebrates-it...
# 2021-03-18  https://news.dunkindonuts.com/news/dunkin-joy-...
# 2021-03-19  https://caternewsdigital.com/internacional/cos...
# 2021-03-20  https://www.infofranquicias.com/fd-1348/franqu...
# 2021-04-28  https://investor.starbucks.com/news/financial-...
# 2021-06-25  https://www.businessinsider.com/starbucks-shor...
# 2021-09-15  https://www.nasdaq.com/articles/starbucks-sbux...
# 2021-10-29  https://www.cnbc.com/2021/10/27/starbucks-to-r...
# 2021-11-01  https://www.coca-colacompany.com/news/coca-col...
# 2022-01-20  https://www.ft.com/content/36294e0f-217f-4447-...
# 2022-03-16  https://edition.cnn.com/2022/03/16/business/st...
# 2022-03-18  https://www.forbes.com/sites/siladityaray/2022...
# 2022-05-04  https://www.cnbc.com/2022/05/03/starbucks-sbux...
# 2022-08-03  https://www.reuters.com/business/retail-consum...
# 2022-08-09  https://www.reuters.com/business/retail-consum...
# 2022-09-13  https://stories.starbucks.com/press/2022/starb...
# 2022-09-14  https://finance.yahoo.com/news/starbucks-bulli...
# 2022-10-24  https://corporate.mcdonalds.com/corpmcd/invest...
# 2022-11-04  https://www.reuters.com/business/retail-consum...
# 2023-02-03  https://www.cnbc.com/2023/02/02/starbucks-sbux...
# 2023-05-03  https://investor.starbucks.com/news/financial-...
# 2023-06-23  https://edition.cnn.com/2023/06/23/business/st...
# 2023-07-21  https://investor.luckincoffee.com/news-release...
# 2023-07-21  https://www.restaurantdive.com/news/starbucks-...
# 2023-08-02  https://investor.starbucks.com/news/financial-...
# 2023-08-02  https://www.reuters.com/business/retail-consum...
# 2023-11-01  https://stories.starbucks.com/press/2023/starb...
# 2023-11-02  https://www.businesswire.com/news/home/2023110...
# 2023-11-03  https://www.moodys.com/credit-ratings/Starbuck...
# 2023-12-04  https://www.reuters.com/business/retail-consum...
# 2024-01-30  https://about.starbucks.com/press/2024/starbuc...
# 2024-01-31  https://www.reuters.com/business/retail-consum...
# 2024-03-15  https://thespoon.tech/not-surprisingly-starbuc...
# 2024-05-01  https://www.reuters.com/business/retail-consum...
# 2024-06-21  https://www.cnn.com/2024/06/21/business/starbu...
# 2024-07-19  https://peltzinternational.com/activist-elliot...
# 2024-08-13  https://about.starbucks.com/press/2024/starbuc...
# 2024-08-14  https://corpgov.law.harvard.edu/2024/10/01/act...
# 2024-10-23  https://www.nasdaq.com/articles/starbucks-slip...
# 2024-11-03  https://larepublica.pe/estados-unidos/2024/11/...
# 2024-12-20                                Datos industria QSR
# 2025-01-29  https://www.reuters.com/business/retail-consum...
# 2025-04-03  https://investor.starbucks.com/events-and-pres...
# 2025-04-07                               Analisis macro China
# 2025-04-09                                       Reportes CPG
# 2025-04-30  https://www.reuters.com/business/starbucks-pos...
# 2025-05-24  https://people.com/mcdonalds-shutting-down-cos...
# 2025-06-27  https://corporate.mcdonalds.com/corpmcd/invest...
# 2025-07-02  https://larepublica.pe/mundo/2025/07/02/la-cad...
# 2025-07-29  https://www.theice.com/products/15/Coffee-C-Fu...
# 2025-07-30                    https://investor.starbucks.com/
# 2026-01-14  https://www.retaildetail.es/news/alimentacion/...
# 2026-01-21                                   Proyecciones QSR
# 2026-01-28  https://www.reuters.com/business/starbucks-see...
#
#                        Impacto_Neto
# Fecha
# 2021-03-16       competencia_global
# 2021-03-17             evento_marca
# 2021-03-18          competencia_qsr
# 2021-03-19          competencia_qsr
# 2021-03-20       competencia_precio
# 2021-04-28                 earnings
# 2021-06-25          shock_operativo
# 2021-09-15      politica_accionista
# 2021-10-29             shock_costos
# 2021-11-01       competencia_retail
# 2022-01-20       competencia_global
# 2022-03-16       choque_estructural
# 2022-03-18         politica_capital
# 2022-05-04              riesgo_pais
# 2022-08-03    estacionalidad_verano
# 2022-08-09       competencia_global
# 2022-09-13         plan_estrategico
# 2022-09-14       revision_analistas
# 2022-10-24          competencia_qsr
# 2022-11-04                 earnings
# 2023-02-03              riesgo_pais
# 2023-05-03                 earnings
# 2023-06-23            shock_laboral
# 2023-07-21       competencia_global
# 2023-07-21           reorganizacion
# 2023-08-02                 earnings
# 2023-08-02     innovacion_operativa
# 2023-11-01   estacionalidad_navidad
# 2023-11-02                 earnings
# 2023-11-03           riesgo_credito
# 2023-12-04          competencia_qsr
# 2024-01-30                 earnings
# 2024-01-31       shock_reputacional
# 2024-03-15          restructuracion
# 2024-05-01            shock_extremo
# 2024-06-21           guerra_precios
# 2024-07-19                activismo
# 2024-08-13       choque_estructural
# 2024-08-14            shock_extremo
# 2024-10-23          restructuracion
# 2024-11-03       competencia_global
# 2024-12-20   estacionalidad_navidad
# 2025-01-29                 earnings
# 2025-04-03  confianza_institucional
# 2025-04-07           guerra_precios
# 2025-04-09       competencia_retail
# 2025-04-30                 earnings
# 2025-05-24          competencia_qsr
# 2025-06-27           guerra_precios
# 2025-07-02       competencia_global
# 2025-07-29             shock_costos
# 2025-07-30                 earnings
# 2026-01-14       competencia_global
# 2026-01-21          competencia_b2b
# 2026-01-28                 earnings

# %%
# 1. Preparar df_anomalies
df_anomalies = df[df['Vol_Anomaly'] == True].reset_index()
# Si Yahoo Finance bajó los datos como 'Date', lo renombramos a 'Fecha'
if 'Date' in df_anomalies.columns:
    df_anomalies = df_anomalies.rename(columns={'Date': 'Fecha'})

# 2. Preparar news
# Aseguramos que news tenga la columna 'Fecha' disponible para el merge
df_news_to_merge = news.reset_index()
if 'index' in df_news_to_merge.columns: # Por si acaso reset_index le puso 'index'
    df_news_to_merge = df_news_to_merge.rename(columns={'index': 'Fecha'})

# 3. Realizar el merge ahora que estamos SEGUROS de que existe 'Fecha' en ambos
df_combined = pd.merge(df_anomalies, df_news_to_merge, on='Fecha', how='left')

# 4. Limpieza de nulos para el gráfico
df_combined['Evento'] = df_combined['Evento'].fillna("Sin evento registrado")
df_combined['Categoria'] = df_combined['Categoria'].fillna("N/A")

# --- De aquí en adelante el código del gráfico es el mismo ---
fig = go.Figure()

# Traza 1: Precio Base
fig.add_trace(go.Scatter(
    x=df.index, y=df['Adj Close'],
    mode="lines", name="Precio SBUX",
    line=dict(color="rgba(0, 112, 74, 0.2)", width=1.5),
    hoverinfo='skip'
))

# Traza 2: Anomalías
fig.add_trace(go.Scatter(
    x=df_combined['Fecha'], 
    y=df_combined['Adj Close'],
    mode="markers", name="Shock Detectado",
    marker=dict(color="red", size=10, symbol="diamond", line=dict(width=1, color="black")),
    text=df_combined['Evento'],
    customdata=np.stack((df_combined['Categoria'], df_combined['Volume']), axis=-1),
    hovertemplate="""
    <b>Fecha:</b> %{x|%d %b %Y}<br>
    <b>Precio:</b> $%{y:.2f}<br>
    <b>Volumen:</b> %{customdata[1]:,.0f}<br>
    <br>
    <b>Evento:</b> %{text}<br>
    <b>Categoría:</b> %{customdata[0]}
    <extra></extra>
    """
))

fig.update_layout(
    title="<b>Análisis de Shocks en Starbucks: Correlación Precio-Evento</b>",
    template="plotly_white", xaxis_title="Eje Temporal", yaxis_title="Precio (USD)",
    width=1300, height=650, xaxis=dict(rangeslider=dict(visible=True))
)

fig.show()

# %% [markdown]
# ### 3. Integración de Análisis Fundamental (Estados Financieros)
# El objetivo es capturar la salud económica de la empresa (Ventas y Márgenes) para justificar los movimientos del precio y generar variables de control para nuestro futuro modelo SARIMAX.
#
# **Pasos a realizar:**
# 1. Descarga del Estado de Resultados Trimestral (Income Statement).
# 2. Limpieza y cálculo de ratios clave ($Margen\ Operativo = \frac{Ingreso\ Operativo}{Ventas\ Totales}$).
# 3. Fusión (Merge) con nuestra serie de tiempo principal usando un "Forward Fill" para que el mercado "recuerde" el último reporte trimestral en sus operaciones diarias.

# %%
import yfinance as yf

ticker = yf.Ticker("SBUX")
df_q = ticker.quarterly_financials  # trimestral
df_q = df_q.loc[["Total Revenue", "Operating Income", "Net Income"]]
df_q = df_q.T
df_q
# Out:
#             Total Revenue  Operating Income   Net Income
# 2025-12-31   9.915100e+09      9.183000e+08  293300000.0
# 2025-09-30   9.569000e+09      9.481000e+08  133200000.0
# 2025-06-30   9.456000e+09      8.993000e+08  558300000.0
# 2025-03-31   8.761600e+09      6.581000e+08  384200000.0
# 2024-12-31   9.397800e+09      1.075200e+09  780800000.0
# 2024-09-30            NaN               NaN          NaN
# 2024-06-30            NaN               NaN          NaN

# %% [markdown]
# > Dado que de `yfinance` solo obtenemos unos pocos últimos trimestres, utilizaremos otra librería para obtener los datos que necesitamos

# %%
# %pip install stockdex
from stockdex import Ticker

# %%
#Cargamos el Ticker y las funciones del Income Statement trimestral
ticker = Ticker("SBUX")
help(ticker.macrotrends_income_statement)
# Out:
# Help on method macrotrends_income_statement in module stockdex.macrotrends_interface:
#
# macrotrends_income_statement(
#     frequency: Literal['quarterly', 'annual'] = 'annual'
# ) -> pd.DataFrame method of stockdex.ticker.Ticker instance
#     Retrieve the income statement for the given ticker.

# %%
# 1. Descargamos el Income Statement trimestral y filtramos las métricas que nos interesan
income_q = ticker.macrotrends_income_statement(frequency="quarterly")
df_metrics = income_q.loc[["Revenue", "Operating Income", "Net Income"]]

# 2. Para filtrar años 2021–2025, filtramos columnas
cols_to_keep = [c for c in df_metrics.columns if c.startswith(("2020", "2021", "2022", "2023", "2024", "2025"))]
df_financials = df_metrics[cols_to_keep].T

# 3. Limpiamos y convertimos a float
df_financials = df_financials.astype(float)  # convierte a float

# 4. Guardamos la data cruda
os.makedirs('../data/raw', exist_ok=True)
finantials_path = '../data/raw/sbux_financials_raw.csv'
df_financials.to_csv(finantials_path)
print(f"Archivo crudo guardado en {finantials_path}")

df_financials
# Out:
# Archivo crudo guardado en ../data/raw/sbux_financials_raw.csv
# field_name   Revenue  Operating Income  Net Income
# 2025-12-31  9915.100          890.7998    293.3000
# 2025-09-30  9568.999          278.2979    133.1001
# 2025-06-30  9456.000          935.5996    558.3000
# 2025-03-31  8761.600          600.9995    384.2000
# 2024-12-31  9397.800         1121.7000    780.8000
# 2024-09-30  9073.999         1307.0010    909.2998
# 2024-06-30  9113.900         1517.5000   1054.8000
# 2024-03-31  8563.000         1098.9000    772.4000
# 2023-12-31  9425.300         1485.3990   1024.4000
# 2023-09-30  9373.600         1706.3010   1219.3000
# 2023-06-30  9168.300         1583.8990   1141.7000
# 2023-03-31  8719.800         1327.5000    908.3000
# 2022-12-31  8713.900         1253.1000    855.2000
# 2022-09-30  8414.201         1195.6010    878.3002
# 2022-06-30  8150.100         1295.5000    912.9000
# 2022-03-31  7635.600          948.8999    674.5000
# 2021-12-31  8050.400         1177.8000    815.9000
# 2021-09-30  8146.700         1482.3010   1764.3000
# 2021-06-30  7496.500         1488.7000   1153.4000
# 2021-03-31  6668.000          987.6001    659.4000
# 2020-12-31  6749.400          913.4995    622.2000
# 2020-09-30  6203.100          558.3989    392.5999
# 2020-06-30  4222.100         -703.8999   -678.4000
# 2020-03-31  5995.700          487.4004    328.4000

# %% [markdown]
# ### 3.1. Limpieza e Ingeniería de Características Financieras
# `yfinance` nos devuelve muchas cuentas contables. Para nuestro modelo, nos centraremos en los "drivers" principales que mueven la acción:
# * **Revenue (Ventas Totales):** Indica si la empresa vende más o menos café.
# * **Operating Income (Ingreso Operativo):** Lo que queda tras pagar costos directos (café, salarios).
# * **Margen Operativo:** Nuestra nueva característica (Feature). Nos dirá la eficiencia real de la empresa.

# %%
# Preparamos la data
df_income = df_financials.copy()

# Aseguramos que el índice sea formato Datetime sin zona hozraria (para evitar problemas al cruzar)
df_income.index = pd.to_datetime(df_income.index).tz_localize(None)
df_income = df_income.sort_index()

# Calculamos el Ratio Financiero Clave
df_income['Margen_Operativo'] = df_income['Operating Income'] / df_income['Revenue']
df_income['Margen_Operativo_%'] = df_income['Margen_Operativo'] * 100

# Guardamos la versión limpia
processed_path = '../data/processed/sbux_financials_clean.csv'
df_income.to_csv(processed_path)
print(f"\nArchivo limpio y calculado guardado como '{processed_path}'")
df_income
# Out:
# Archivo limpio y calculado guardado como '../data/processed/sbux_financials_clean.csv'
# field_name   Revenue  Operating Income  Net Income  Margen_Operativo  \
# 2020-03-31  5995.700          487.4004    328.4000          0.081292
# 2020-06-30  4222.100         -703.8999   -678.4000         -0.166718
# 2020-09-30  6203.100          558.3989    392.5999          0.090019
# 2020-12-31  6749.400          913.4995    622.2000          0.135345
# 2021-03-31  6668.000          987.6001    659.4000          0.148110
# 2021-06-30  7496.500         1488.7000   1153.4000          0.198586
# 2021-09-30  8146.700         1482.3010   1764.3000          0.181951
# 2021-12-31  8050.400         1177.8000    815.9000          0.146303
# 2022-03-31  7635.600          948.8999    674.5000          0.124273
# 2022-06-30  8150.100         1295.5000    912.9000          0.158955
# 2022-09-30  8414.201         1195.6010    878.3002          0.142093
# 2022-12-31  8713.900         1253.1000    855.2000          0.143805
# 2023-03-31  8719.800         1327.5000    908.3000          0.152240
# 2023-06-30  9168.300         1583.8990   1141.7000          0.172758
# 2023-09-30  9373.600         1706.3010   1219.3000          0.182033
# 2023-12-31  9425.300         1485.3990   1024.4000          0.157597
# 2024-03-31  8563.000         1098.9000    772.4000          0.128331
# 2024-06-30  9113.900         1517.5000   1054.8000          0.166504
# 2024-09-30  9073.999         1307.0010    909.2998          0.144038
# 2024-12-31  9397.800         1121.7000    780.8000          0.119358
# 2025-03-31  8761.600          600.9995    384.2000          0.068595
# 2025-06-30  9456.000          935.5996    558.3000          0.098942
# 2025-09-30  9568.999          278.2979    133.1001          0.029083
# 2025-12-31  9915.100          890.7998    293.3000          0.089843
#
# field_name  Margen_Operativo_%
# 2020-03-31            8.129166
# 2020-06-30          -16.671796
# 2020-09-30            9.001933
# 2020-12-31           13.534529
# 2021-03-31           14.811039
# 2021-06-30           19.858601
# 2021-09-30           18.195110
# 2021-12-31           14.630329
# 2022-03-31           12.427313
# 2022-06-30           15.895510
# 2022-09-30           14.209323
# 2022-12-31           14.380473
# 2023-03-31           15.223973
# 2023-06-30           17.275820
# 2023-09-30           18.203262
# 2023-12-31           15.759700
# 2024-03-31           12.833119
# 2024-06-30           16.650391
# 2024-09-30           14.403804
# 2024-12-31           11.935772
# 2025-03-31            6.859472
# 2025-06-30            9.894243
# 2025-09-30            2.908328
# 2025-12-31            8.984274

# %% [markdown]
# > Observemos la columna ``Margen_Operativo_%``.
# > Se muestra que a inicios de 2024 (cerca de la crisis que vimos en la gráfica) este margen cae por debajo del 14%, esto es, desplome del precio de la acción esta justificado por una pérdida real de eficiencia, no solo por "pánico de mercado".

# %% [markdown]
# #### 3.2. Fusión de Datos y Creación de Variables Dummy (SARIMAX)
# Ahora vamos a integrar todo. Tomaremos nuestro DataFrame principal (precios y volumen), le pegaremos los datos financieros trimestrales (rellenando los vacíos diarios) y usaremos nuestro archivo `news_history.csv` para crear las **Variables de Intervención (Dummies)**.
#
# * **Dummy de Pulso (Pulse):** Un "1" solo en el día del evento (Ej. Publicación de un reporte). Mide shocks a corto plazo.
# * **Dummy de Escalón (Step):** Un "1" a partir del día del evento en adelante (Ej. El cambio de CEO a Brian Niccol). Mide cambios estructurales.

# %% [markdown]
# ``Cruzamos Estados Financieros...``

# %%
df_master = df.join(df_income[['Margen_Operativo_%', 'Revenue']], how='left')
df_master['Margen_Operativo_%'] = df_master['Margen_Operativo_%'].ffill()
df_master['Revenue'] = df_master['Revenue'].ffill()
#ahora eliminamos los registros que tengan alguna columna financiera nula (antes de cruzar con noticias)
df_master = df_master.dropna(subset=['Margen_Operativo_%', 'Revenue'])

df_master['Fecha'] = pd.to_datetime(df_master.index)
df_master
# Out:
#              Adj Close   Volume  Vol_Avg_20  Vol_Anomaly  Log_Return  \
# Date
# 2021-03-31   97.421112  6478400   7244615.0        False   -0.009110
# 2021-04-01   97.519173  5793000   7173675.0        False    0.001006
# 2021-04-05   98.981331  6913100   7241335.0        False    0.014882
# 2021-04-06  100.880363  6745200   7322620.0        False    0.019004
# 2021-04-07  100.916023  5629600   7328555.0        False    0.000353
# ...                ...      ...         ...          ...         ...
# 2026-02-09   98.345779  7150600  11434955.0        False   -0.004737
# 2026-02-10   96.905067  8543500  11497655.0        False   -0.014758
# 2026-02-11   98.484879  6949100  11567015.0        False    0.016171
# 2026-02-12   96.139999  9537300  11625220.0        False   -0.024098
# 2026-02-13   93.790001  8948000  11572535.0        False   -0.024747
#
#             Margen_Operativo_%  Revenue      Fecha
# Date
# 2021-03-31           14.811039   6668.0 2021-03-31
# 2021-04-01           14.811039   6668.0 2021-04-01
# 2021-04-05           14.811039   6668.0 2021-04-05
# 2021-04-06           14.811039   6668.0 2021-04-06
# 2021-04-07           14.811039   6668.0 2021-04-07
# ...                        ...      ...        ...
# 2026-02-09            8.984274   9915.1 2026-02-09
# 2026-02-10            8.984274   9915.1 2026-02-10
# 2026-02-11            8.984274   9915.1 2026-02-11
# 2026-02-12            8.984274   9915.1 2026-02-12
# 2026-02-13            8.984274   9915.1 2026-02-13
#
# [1225 rows x 8 columns]

# %% [markdown]
# ``Cargamos las Noticias por Impacto y definimos nuestras Dummies...``

# %%
df_news = pd.read_csv('../data/external/news_history.csv', parse_dates=['Fecha'])

# 3. INICIALIZAMOS LAS 8 DUMMIES
dummies = [
    'choque_estructural',
    'shock_extremo',
    'earnings',
    'riesgo_pais',
    'shock_costos'
]

for d in dummies:
    df_master[d] = 0

# 4. FUNCIONES DE INTERVENCIÓN
def pulse(df, date, col):
    if date in df.index:
        df.loc[date, col] = 1

def step(df, date, col):
    df.loc[date:, col] = 1

def window(df, date, col, days):
    end = date + pd.Timedelta(days=days)
    df.loc[(df.index >= date) & (df.index <= end), col] = 1
    
# 5. ASIGNAMOS DUMMIES SEGÚN IMPACTO_NETO
for _, row in df_news.iterrows():

    fecha = row['Fecha']
    tipo = row['Impacto_Neto']

    if tipo == 'shock_extremo':
        pulse(df_master, fecha, 'shock_extremo')

    elif tipo == 'choque_estructural':
        step(df_master, fecha, 'choque_estructural')

    elif tipo == 'earnings':
        window(df_master, fecha, 'earnings', 5)

    elif tipo == 'riesgo_pais':
        window(df_master, fecha, 'riesgo_pais', 21)

    elif tipo == 'shock_costos':
        window(df_master, fecha, 'shock_costos', 42)

# 6. EXPORTAMOS DATASET FINAL
path_final = '../data/transformed/sbux_master_sarimax.csv'
df_master.to_csv(path_final)

print(f"Dataset SARIMAX guardado como {path_final}")

# Visualización rápida
df_master[dummies].sum()
# Out:
# Dataset SARIMAX guardado como ../data/transformed/sbux_master_sarimax.csv
# choque_estructural    983
# shock_extremo           2
# earnings               40
# riesgo_pais            31
# shock_costos           60
# dtype: int64

# %%
df_master
# Out:
#              Adj Close   Volume  Vol_Avg_20  Vol_Anomaly  Log_Return  \
# Date
# 2021-03-31   97.421112  6478400   7244615.0        False   -0.009110
# 2021-04-01   97.519173  5793000   7173675.0        False    0.001006
# 2021-04-05   98.981331  6913100   7241335.0        False    0.014882
# 2021-04-06  100.880363  6745200   7322620.0        False    0.019004
# 2021-04-07  100.916023  5629600   7328555.0        False    0.000353
# ...                ...      ...         ...          ...         ...
# 2026-02-09   98.345779  7150600  11434955.0        False   -0.004737
# 2026-02-10   96.905067  8543500  11497655.0        False   -0.014758
# 2026-02-11   98.484879  6949100  11567015.0        False    0.016171
# 2026-02-12   96.139999  9537300  11625220.0        False   -0.024098
# 2026-02-13   93.790001  8948000  11572535.0        False   -0.024747
#
#             Margen_Operativo_%  Revenue      Fecha  choque_estructural  \
# Date
# 2021-03-31           14.811039   6668.0 2021-03-31                   0
# 2021-04-01           14.811039   6668.0 2021-04-01                   0
# 2021-04-05           14.811039   6668.0 2021-04-05                   0
# 2021-04-06           14.811039   6668.0 2021-04-06                   0
# 2021-04-07           14.811039   6668.0 2021-04-07                   0
# ...                        ...      ...        ...                 ...
# 2026-02-09            8.984274   9915.1 2026-02-09                   1
# 2026-02-10            8.984274   9915.1 2026-02-10                   1
# 2026-02-11            8.984274   9915.1 2026-02-11                   1
# 2026-02-12            8.984274   9915.1 2026-02-12                   1
# 2026-02-13            8.984274   9915.1 2026-02-13                   1
#
#             shock_extremo  earnings  riesgo_pais  shock_costos
# Date
# 2021-03-31              0         0            0             0
# 2021-04-01              0         0            0             0
# 2021-04-05              0         0            0             0
# 2021-04-06              0         0            0             0
# 2021-04-07              0         0            0             0
# ...                   ...       ...          ...           ...
# 2026-02-09              0         0            0             0
# 2026-02-10              0         0            0             0
# 2026-02-11              0         0            0             0
# 2026-02-12              0         0            0             0
# 2026-02-13              0         0            0             0
#
# [1225 rows x 13 columns]
